# %% [markdown]
# Assignment 01: Python Coding Exercises
#
# Name: Yash Wadhwa
# NUID: 002778382

# %% [markdown]
# Q1) Perform the following list operations:

# %% [markdown]
# a. maximum number in a list of numbers

# %%
numbers = [11, 3, 30, 9, 16, 54,33, 7]
max_no = 0

for number in numbers:
    if number > max_no:
        max_no = number
print(max_no)
# Out:
# 54

# %% [markdown]
# b. concatenate two lists

# %%
list1 = [23, 35, 57, 79, 113, 9]
list2 = [36, 48, 15, 12, 2, 4]

for number in list2:
  list1.append(number)
print(list1)
# Out:
# [23, 35, 57, 79, 113, 9, 36, 48, 15, 12, 2, 4]

# %% [markdown]
# c. reverse a list

# %%
list_numbers = [11, 3, 30, 9, 16, 54]
reversed_list = list_numbers[::-1]
print(reversed_list)
# Out:
# [54, 16, 9, 30, 3, 11]

# %% [markdown]
# d. interchange the first and the last elements in a list

# %%
list1 = [36, 48, 15, 12, 2]

list1[0],list1[-1] = list1[-1],list1[0]
print(list1)
# Out:
# [2, 48, 15, 12, 36]

# %% [markdown]
# e. search if a given string is a substring of a list of strings

# %%
list_of_strings= ["My name is Yash", "I am a student at Northeastern University", "Football"]
user_input = input("Enter the string to search ")
count = 0
for substr in list_of_strings:
    if substr.find(user_input) != -1:
      count += 1
if count > 0:
  print(f'Entered substring was found {count} times')
else:
  print("Entered string is not a substring")
# Out:
# Entered substring was found 1 times

# %% [markdown]
# Q2) Write a Python program to delete an element from a list by index.

# %%
numbers = [56, 71, 14, 1, 46, 8]
inp = input("Enter the index of element to delete ")
numbers.pop(int(inp))
print(numbers)
# Out:
# [56, 71, 1, 46, 8]

# %% [markdown]
# Q3) Write a Python program to check whether the given number is even or not.

# %%
number = int(input("Enter the number to check "))
if number % 2 == 0:
    print("Entered no is even")
else:
    print("Entered no is odd")
# Out:
# Entered no is odd

# %% [markdown]
# Q4) Write a program which can compute the factorial of a given number. Make sure to take into account the exceptions like a negative number.

# %%
number = int(input("Enter number to find factorial "))
factorial = 1

if number < 0:
    print("Factorial cannot be calculated for a negative number")
elif number == 0:
    print("Factorial of 0 is 1")
else:
    for num in range(1, number + 1):
        factorial = factorial * num
    print(factorial)
# Out:
# 25852016738884976640000

# %% [markdown]
# Q5) Write a Python program to create a dictionary and display both the keys and values sorted in alphabetical order by the key.

# %%
basicinfo = dict()

n = int(input("Enter the number of users "))
for i in range(n):
    usr_name = input("Enter name of the user ")
    age = input("Enter age of the user ")
    basicinfo[usr_name] = age
print("Information of the users", basicinfo)

keys = basicinfo.keys()
print(keys)
sorted_keys = sorted(keys)

sorted_basicinfo = {}
for key in sorted_keys:
  sorted_basicinfo[key] = basicinfo[key]
print(sorted_basicinfo)
# Out:
# Information of the users {'Yash': '25'}
# dict_keys(['Yash'])
# {'Yash': '25'}

# %% [markdown]
# Q6) Write a lambda function to compute log values of only positive numbers, else return “Invalid”.

# %%
import math
number = int(input("Enter number to find the log value"))

if number < 0:
  print("Invalid")
else:
  calc_log = lambda x: math.log10(x)
  print(calc_log(number))
# Out:
# 0.47712125471966244

# %% [markdown]
# Q7) Write a function to add elements of two input matrices.

# %%
order = int(input("Enter order of the matrix"))

a =[]
b =[]
result_matrix = []
print("Enter elements of the matrix for each row ")

for i in range(order):  
  row =[]        
  for j in range(order):
      row.append(int(input()))
  a.append(row)

for i in range(order):   
  row =[]       
  for j in range(order):
      row.append(int(input()))
  b.append(row)

result_matrix = [[a[i][j] + b[i][j] for j in range(order)] for i in range(order)]
print(result_matrix)
# Out:
# Enter elements of the matrix for each row
# [[6, 8], [10, 12]]

# %% [markdown]
# Q8) Create your own Pandas dataframe df with three columns and a dozen rows. Do the following operations:
# • Insert a new column to df.
# • Add a new tuple to df.
# • Iterate over the rows of df and display.
# • Display the column names of df.
# • Drop a list of rows based on some criterion applied to the first column (e.g., if the first column is an integer column then all rows with values of the first column greater than 25).
# • Export df into an excel file and then import from the same.
# • Replace all the NaN values with zeros in a column of df.
# • Set a given value for a particular cell in df.
# • Divide df into in a given ratio.
# • Rename a specific column name.
# • Display the last three rows of df.

# %%
import pandas as pd

data = {
    "Name":["Yash", "Harsh", "Tanuj", "Shubham", "Stephen", "Lexi", "Patricia", "Bobby", "Hitesh", "Rick", "Shriya", "Morty"],
    "Age":[25, 21, 23, 26, 22, 26, 29, 21, 22, 28, 25, 31],
    "Student_ID":[212340, 212341, 212342, 212343, 212344, 212345, 212346, 212347, 212348, 212349, 212350, 212351]
}

df = pd.DataFrame(data, columns = ["Name", "Age", "Student_ID"])
df
# Out:
#         Name  Age  Student_ID
# 0       Yash   25      212340
# 1      Harsh   21      212341
# 2      Tanuj   23      212342
# 3    Shubham   26      212343
# 4    Stephen   22      212344
# 5       Lexi   26      212345
# 6   Patricia   29      212346
# 7      Bobby   21      212347
# 8     Hitesh   22      212348
# 9       Rick   28      212349
# 10    Shriya   25      212350
# 11     Morty   31      212351

# %% [markdown]
# • Insert a new column to df.

# %%
game = ["Football", "Throwball", "Cricket", "Ice Hockey", "Baseball", "Ice Skating", "Snooker", "Handball", "", "Hockey", "Swimming", "Rugby"]
df["Game"] = game
df
# Out:
#         Name  Age  Student_ID         Game
# 0       Yash   25      212340     Football
# 1      Harsh   21      212341    Throwball
# 2      Tanuj   23      212342      Cricket
# 3    Shubham   26      212343   Ice Hockey
# 4    Stephen   22      212344     Baseball
# 5       Lexi   26      212345  Ice Skating
# 6   Patricia   29      212346      Snooker
# 7      Bobby   21      212347     Handball
# 8     Hitesh   22      212348
# 9       Rick   28      212349       Hockey
# 10    Shriya   25      212350     Swimming
# 11     Morty   31      212351        Rugby

# %% [markdown]
# • Add a new tuple to df.

# %%
data_tuple = ("Loki", 22, "212352","Boxing") 

df.loc[len(df.index)] = data_tuple
  
print(df)
# Out:
#         Name  Age Student_ID         Game
# 0       Yash   25     212340     Football
# 1      Harsh   21     212341    Throwball
# 2      Tanuj   23     212342      Cricket
# 3    Shubham   26     212343   Ice Hockey
# 4    Stephen   22     212344     Baseball
# 5       Lexi   26     212345  Ice Skating
# 6   Patricia   29     212346      Snooker
# 7      Bobby   21     212347     Handball
# 8     Hitesh   22     212348
# 9       Rick   28     212349       Hockey
# 10    Shriya   25     212350     Swimming
# 11     Morty   31     212351        Rugby
# 12      Loki   22     212352       Boxing

# %% [markdown]
# • Iterate over the rows of df and display.

# %%
print("Iterating the df over rows")
print()
for i,j in df.iterrows():
  print(i,j)
  print()
# Out:
# Iterating the df over rows
#
# 0 Name              Yash
# Age                 25
# Student_ID      212340
# Game          Football
# Name: 0, dtype: object
#
# 1 Name              Harsh
# Age                  21
# Student_ID       212341
# Game          Throwball
# Name: 1, dtype: object
#
# 2 Name            Tanuj
# Age                23
# Student_ID     212342
# Game          Cricket
# Name: 2, dtype: object
#
# 3 Name             Shubham
# Age                   26
# Student_ID        212343
# Game          Ice Hockey
# Name: 3, dtype: object
#
# 4 Name           Stephen
# Age                 22
# Student_ID      212344
# Game          Baseball
# Name: 4, dtype: object
#
# 5 Name                 Lexi
# Age                    26
# Student_ID         212345
# Game          Ice Skating
# Name: 5, dtype: object
#
# 6 Name          Patricia
# Age                 29
# Student_ID      212346
# Game           Snooker
# Name: 6, dtype: object
#
# 7 Name             Bobby
# ...

# %% [markdown]
# • Display the column names of df.

# %%
print(list(df.columns))
# Out:
# ['Name', 'Age', 'Student_ID', 'Game']

# %% [markdown]
# • Drop a list of rows based on some criterion applied to the first column (e.g., if the first column is an integer column then all rows with values of the first column greater than 25).

# %%
df_filtered = df[df["Age"]> 27]
print(df_filtered)
# Out:
#         Name  Age Student_ID     Game
# 6   Patricia   29     212346  Snooker
# 9       Rick   28     212349   Hockey
# 11     Morty   31     212351    Rugby

# %% [markdown]
# • Export df into an excel file and then import from the same.

# %%
fileName = "DFData.xlsx"
df.to_csv(fileName)
print("Data exported to Excel")
# Out:
# Data exported to Excel

# %% [markdown]
# • Replace all the NaN values with zeros in a column of df.

# %%
new_df = df.fillna(0)
new_df
# Out:
#         Name  Age Student_ID         Game
# 0       Yash   25     212340     Football
# 1      Harsh   21     212341    Throwball
# 2      Tanuj   23     212342      Cricket
# 3    Shubham   26     212343   Ice Hockey
# 4    Stephen   22     212344     Baseball
# 5       Lexi   26     212345  Ice Skating
# 6   Patricia   29     212346      Snooker
# 7      Bobby   21     212347     Handball
# 8     Hitesh   22     212348
# 9       Rick   28     212349       Hockey
# 10    Shriya   25     212350     Swimming
# 11     Morty   31     212351        Rugby
# 12      Loki   22     212352       Boxing

# %% [markdown]
# • Set a given value for a particular cell in df.

# %%
df.loc[4,'Game'] = ""
df
# Out:
#         Name  Age Student_ID         Game
# 0       Yash   25     212340     Football
# 1      Harsh   21     212341    Throwball
# 2      Tanuj   23     212342      Cricket
# 3    Shubham   26     212343   Ice Hockey
# 4    Stephen   22     212344
# 5       Lexi   26     212345  Ice Skating
# 6   Patricia   29     212346      Snooker
# 7      Bobby   21     212347     Handball
# 8     Hitesh   22     212348
# 9       Rick   28     212349       Hockey
# 10    Shriya   25     212350     Swimming
# 11     Morty   31     212351        Rugby
# 12      Loki   22     212352       Boxing

# %% [markdown]
# • Divide df into in a given ratio.

# %%
df_slice1 = df.sample(frac = 0.5)
df_slice2 = df.drop(df_slice1.index)
#df_slice1
df_slice2
# Out:
#        Name  Age Student_ID        Game
# 0      Yash   25     212340    Football
# 3   Shubham   26     212343  Ice Hockey
# 4   Stephen   22     212344
# 7     Bobby   21     212347    Handball
# 9      Rick   28     212349      Hockey
# 10   Shriya   25     212350    Swimming
# 11    Morty   31     212351       Rugby

# %% [markdown]
# • Rename a specific column name.

# %%
df.columns = df.columns.str.replace('Game', 'Sport')
df
# Out:
#         Name  Age Student_ID        Sport
# 0       Yash   25     212340     Football
# 1      Harsh   21     212341    Throwball
# 2      Tanuj   23     212342      Cricket
# 3    Shubham   26     212343   Ice Hockey
# 4    Stephen   22     212344
# 5       Lexi   26     212345  Ice Skating
# 6   Patricia   29     212346      Snooker
# 7      Bobby   21     212347     Handball
# 8     Hitesh   22     212348
# 9       Rick   28     212349       Hockey
# 10    Shriya   25     212350     Swimming
# 11     Morty   31     212351        Rugby
# 12      Loki   22     212352       Boxing

# %% [markdown]
# • Display the last three rows of df.

# %%
print(df[9:])
# Out:
#       Name  Age Student_ID     Sport
# 9     Rick   28     212349    Hockey
# 10  Shriya   25     212350  Swimming
# 11   Morty   31     212351     Rugby
# 12    Loki   22     212352    Boxing

# %% [markdown]
# Q9) With a given list of numbers, write a program to print this list after removing all duplicate values with the original order reserved.

# %%
numbers = [6, 48, 15, 12, 35, 15]
duplicates_free = []
result = []
[duplicates_free.append(x) for x in numbers if x not in duplicates_free]
result = duplicates_free[::-1]
print(result)
# Out:
# [35, 12, 15, 48, 6]

# %% [markdown]
# Q10) Write a program which counts and prints the numbers of each character in a string input by console.

# %%
string =input("Enter the string\n")
new_str = list(string)
new_list = []

for i in new_str:
    if i not in new_list:
        new_list.append(i)
        count =0
        
        for j in range(len(new_str)):
            if i == new_str[j]:
                count += 1
        print(f'{i} - {count}')
# Out:
# a - 2
# b - 2
# c - 2

# %% [markdown]
# Q11) Check if a given string is symmetrical and palindrome or not. A string is said to be symmetrical if both the halves of the string are the same and a string is said to be a palindrome string if one half of the string is the reverse of the other half or if a string appears same when read forward or backward. The string “malayalam” is palindrome, “byebye” is symmetrical.

# %%
string =input("ENter the string to check ")
half = int(len(string) / 2)
 
if len(string) % 2 == 0:  
    first_str = string[:half]
    second_str = string[half:]
else:  
    first_str = string[:half]
    second_str = string[half+1:]
    
if first_str == second_str:
    print(f'The entered string - {string} is symmetrical')
elif first_str == second_str[::-1]:
    print(f'The entered string - {string} is palindrome')
else:
    print(f'The entered string - {string} is neither palindrome nor symmetrical')
# Out:
# The entered string - byebye is symmetrical

# %% [markdown]
# Q12) Write a Python program to find the n-th term in a Fibonacci series using recursion.

# %%
num = int(input("Enter the term to search "))
def calc_fibonacci(num):
    if num<= 0:
        print("Cannot be calculated for zero")
    elif num == 1:
        return 0
    elif num == 2:
        return 1
    else:
        return calc_fibonacci(num-1)+calc_fibonacci(num-2) 
print(calc_fibonacci(num))
# Out:
# 2

# %% [markdown]
# Q13) Write a Python program to find the longest substring between two given strings. You may not use any package except the substring function but you can make use of recursive function.

# %%
str1 = ("My Name is Yash")
str2 = ("His Name is Harsh")
def longest_common_substring(str1, str2):
    m = [[0] * (1 + len(str2)) for i in range (1 + len(str1))]
    longest, x_longest = 0, 0
    for x in range(1, 1 + len(str1)):
        for y in range(1, 1 + len(str2)):
            if str1[x - 1] == str2[y - 1]:
                m[x][y] = m[x - 1][y - 1] + 1
                if m[x][y] > longest:
                    longest = m[x][y]
                    x_longest = x
                else:
                    m[x][y] = 0
    return str1[x_longest - longest: x_longest]
ans = longest_common_substring(str1,str2)
print(ans)
# Out:
#  Name is

# %% [markdown]
# Q14) Write a Python program which accepts basic mathematical expressions from console and print the evaluation result.

# %%
string = input("Enter the expression you wish to evaluate ")
print(eval(string))
# Out:
# 3

# %% [markdown]
# Q15) Read the loan data file into a dataframe and then compute the following:
# • mean and variance of the Age column,
# • correlation coefficient between the two numerical columns Age and Time_at_address,
# • the conditional probability p(Decision = reject | Occupation = Unemployed),
# • frequency of values in the Job-status column and then draw a bar diagram using matplotlib.

# %%
import pandas as pd

datafile = pd.read_excel("/Users/wadhwa/Desktop/dsem/assignment-1/loan.xlsx")
datafile
# Out:
#     Sex        Age  Time_at_address Res_status  Telephone Occupation  \
# 0     M  50.750000            0.585      owner      given  unemploye
# 1     M  19.670000           10.000       rent  not_given   labourer
# 2     F  52.830002           15.000      owner      given  creative_
# 3     M  22.670000            2.540       rent  not_given  creative_
# 4     M  29.250000           13.000      owner      given     driver
# ..   ..        ...              ...        ...        ...        ...
# 424   M  34.169998            2.750      owner      given  guard_etc
# 425   F  22.250000            1.250       rent  not_given  unemploye
# 426   M  23.330000            1.500      owner      given  creative_
# 427   M  21.000000            4.790       rent  not_given  productio
# 428   M  27.750000            1.290      owner      given   labourer
#
#     Job_status  Time_employed  Time_bank Liab_ref    Acc_ref  Home_Expn  \
# ...

# %% [markdown]
# • mean and variance of the Age column

# %%
mean = datafile['Age'].mean()
print(mean)
variance = datafile['Age'].var()
print (variance)
# Out:
# 31.51016316713987
# 140.27074594116948

# %% [markdown]
# • correlation coefficient between the two numerical columns Age and Time_at_address,

# %%
corr_coeff = datafile.corr()
print(corr_coeff.loc['Age', 'Time_at_address'])
# Out:
# 0.21734150131364374
# /var/folders/cp/llttj8tn31qg0wsrjzjyptz40000gn/T/ipykernel_25455/223167162.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_coeff = datafile.corr()

# %% [markdown]
# • the conditional probability p(Decision = reject | Occupation = Unemployed)

# %%
count_unemp_stat = datafile['Job_status'] =='unemployee'
count_unemp_dec = datafile['Decision'] == 'reject'

p_ab = datafile[(datafile['Job_status'] == 'unemploye') & (datafile['Decision'] == 'reject')] 
p_b = datafile[datafile['Decision'] == 'reject']
cond_prob = len(p_ab)/len(p_b)

cond_prob
# Out:
# 0.11392405063291139

# %% [markdown]
# • frequency of values in the Job-status column and then draw a bar diagram using matplotlib.

# %%
freq = datafile['Job_status'].value_counts()
freq
# Out:
# private_s    265
# governmen     82
# self_empl     37
# unemploye     31
# retired        8
# student        5
# military       1
# Name: Job_status, dtype: int64

# %%
import matplotlib.pyplot as plt

x = ['private_s', 'governmen','self_empl','unemploye','retired','student', 'military']
y = [265,82,37,31,8,5,1]
fig = plt.figure()
axes = fig.add_axes([0,0,2,2])
axes.bar(x,y)
plt.xlabel('Job_status')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Q16) Suppose the loan data file provides some examples of applications to accept or reject, as specified in the Decision column N, given the input background i6nfo in columns A-M. Come up with various ways to find out the degree of relevance between each input “categorical” column of A-M and the Decision column N. (hint. Chi-Square Test of Independence and Mutual Information)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression
data = datafile.values
x = data[:,:-1]
y = data[:,-1:]
print(x.shape)
print(y.shape)
# Out:
# (429, 13)
# (429, 1)

# %%
oneHotEncoder=OneHotEncoder(handle_unknown='ignore')
oneHotEncoder.fit(x)
x_transform=oneHotEncoder.transform(x)
labelEncoder=LabelEncoder()
labelEncoder.fit(y)
y_transform=labelEncoder.transform(y)
# Out:
# /Users/wadhwa/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/wadhwa/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
selectK = SelectKBest(score_func=chi2,k=13)
fit = selectK.fit(x_transform,y_transform)
print(fit)
# Out:
# SelectKBest(k=13, score_func=<function chi2 at 0x14ca96e50>)

# %%
for i in range(len(fit.scores_)):
	print("Feature: ", i , ":","Degree of relevance: ",fit.scores_[i] )
# Out:
# Feature:  0 : Degree of relevance:  0.8040396830856712
# Feature:  1 : Degree of relevance:  0.38129716929836044
# Feature:  2 : Degree of relevance:  0.8101265822784811
# Feature:  3 : Degree of relevance:  0.8101265822784811
# Feature:  4 : Degree of relevance:  1.234375
# Feature:  5 : Degree of relevance:  0.8101265822784811
# Feature:  6 : Degree of relevance:  0.8101265822784811
# Feature:  7 : Degree of relevance:  0.022250791139240486
# Feature:  8 : Degree of relevance:  0.8101265822784811
# Feature:  9 : Degree of relevance:  1.6202531645569622
# Feature:  10 : Degree of relevance:  1.6202531645569622
# Feature:  11 : Degree of relevance:  1.6202531645569622
# Feature:  12 : Degree of relevance:  0.8101265822784811
# Feature:  13 : Degree of relevance:  0.8101265822784811
# Feature:  14 : Degree of relevance:  0.8101265822784811
# Feature:  15 : Degree of relevance:  0.022250791139240486
# Feature:  16 : Degree of relevance:  1.234375
# ...

# %%
Expected_Values=val[3]
no_of_rows=len(df_table.iloc[0:2,0])
no_of_columns=len(df_table.iloc[0,0:2])
dof=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:",dof)
alpha = 0.05
# Out:
# Degree of Freedom: 1

# %% [markdown]
# Q17) Define a class, called Lunch, with __init__() method should have two arguments, self and menu, where menu is a string. Add a method called menu_price. It will involve an if statement: if "menu 1" then print "Price 12.00", if "menu 2" then print "Price 13.40", else print "Error in menu". Test with Paul = Lunch("menu 1") and call Paul.menu_price().

# %%
class Lunch:
    
    def __init__(self, menu):
        self.menu = menu
     
    
    def menu_price(self):
        if self.menu == "menu 1":
            return "Price 12.00"
        elif self.menu == "menu 2":
            return "Price 13.40"
        else:
            return "Error in menu"
        
        
Paul = Lunch("menu 1")
Paul.menu_price()
# Out:
# 'Price 12.00'

# %% [markdown]
# Q18) In the Kaggle insurance data set (https://www.kaggle.com/c/prudential-life-insurance-assessment/data), the Response column is the output variable and the rest are input variables. Perform the following:
# • Fill in the missing values applying an appropriate technique.
# • Make use of the insurance data set to explore the multicollinearity among the input variables.
# • Single out three input variables that are most relevant to predicting the output variable.

# %% [markdown]
# • Fill in the missing values applying an appropriate technique.

# %%
import pandas as pd

df = pd.read_csv("/Users/wadhwa/Desktop/dsem/assignment-1/train.csv")
df
# Out:
#           Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0          2               1             D3              10        0.076923
# 1          5               1             A1              26        0.076923
# 2          6               1             E1              26        0.076923
# 3          7               1             D4              10        0.487179
# 4          8               1             D2              26        0.230769
# ...      ...             ...            ...             ...             ...
# 59376  79142               1             D1              10        0.230769
# 59377  79143               1             D3              26        0.230769
# 59378  79144               1             E1              26        0.076923
# 59379  79145               1             D2              10        0.230769
# 59380  79146               1             A8              26        0.076923
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                    0
# Product_Info_1        0
# Product_Info_2        0
# Product_Info_3        0
# Product_Info_4        0
#                      ..
# Medical_Keyword_45    0
# Medical_Keyword_46    0
# Medical_Keyword_47    0
# Medical_Keyword_48    0
# Response              0
# Length: 128, dtype: int64

# %% [markdown]
# • Make use of the insurance data set to explore the multicollinearity among the input variables.

# %%
df.fillna(df.mean().round(1), inplace = True)
df.isnull().sum()
# Out:
# /var/folders/cp/llttj8tn31qg0wsrjzjyptz40000gn/T/ipykernel_25455/4252037923.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean().round(1), inplace = True)
# Id                    0
# Product_Info_1        0
# Product_Info_2        0
# Product_Info_3        0
# Product_Info_4        0
#                      ..
# Medical_Keyword_45    0
# Medical_Keyword_46    0
# Medical_Keyword_47    0
# Medical_Keyword_48    0
# Response              0
# Length: 128, dtype: int64

# %%
df.drop(['Product_Info_2'],axis=1,inplace=True)
df.head()
# Out:
#    Id  Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 0   2               1              10        0.076923               2
# 1   5               1              26        0.076923               2
# 2   6               1              26        0.076923               2
# 3   7               1              10        0.487179               2
# 4   8               1              26        0.230769               2
#
#    Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt  ...  \
# 0               1               1  0.641791  0.581818  0.148536  ...
# 1               3               1  0.059701  0.600000  0.131799  ...
# 2               3               1  0.029851  0.745455  0.288703  ...
# 3               3               1  0.164179  0.672727  0.205021  ...
# 4               3               1  0.417910  0.654545  0.234310  ...
#
#    Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# 0                   0                   0                   0
# ...

# %%
vectorized_df = df.iloc[:,:-1]
vectorized_df.head()
# Out:
#    Id  Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 0   2               1              10        0.076923               2
# 1   5               1              26        0.076923               2
# 2   6               1              26        0.076923               2
# 3   7               1              10        0.487179               2
# 4   8               1              26        0.230769               2
#
#    Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt  ...  \
# 0               1               1  0.641791  0.581818  0.148536  ...
# 1               3               1  0.059701  0.600000  0.131799  ...
# 2               3               1  0.029851  0.745455  0.288703  ...
# 3               3               1  0.164179  0.672727  0.205021  ...
# 4               3               1  0.417910  0.654545  0.234310  ...
#
#    Medical_Keyword_39  Medical_Keyword_40  Medical_Keyword_41  \
# 0                   0                   0                   0
# ...

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
variance=pd.DataFrame()
variance['Columns']=vectorized_df.columns
vectorized_df.astype(float)
variance['Values'] = [variance_inflation_factor(vectorized_df.values, i) for i in range(vectorized_df.shape[1])]
variance.head()
# Out:
#           Columns      Values
# 0              Id    4.004379
# 1  Product_Info_1   43.328756
# 2  Product_Info_3   62.855906
# 3  Product_Info_4    3.353211
# 4  Product_Info_5  579.796266

# %%
relevent_var=variance.sort_values('Values',ascending=False)
relevent_var.head(3)
# Out:
#                Columns       Values
# 42   Medical_History_6  2589.200015
# 8                   Ht  2208.614325
# 62  Medical_History_26  2094.508318
